# %% [markdown]
# <a href="https://colab.research.google.com/github/ochiait/my_enpit/blob/master/llm_jp_3_1_1_8b_instruct4%E3%81%AE%E5%AE%9F%E8%A1%8C%EF%BC%882025%E5%B9%B411%E6%9C%88%E7%89%88%EF%BC%89.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 松尾研LLMコミュニティ (https://linktr.ee/matsuolab_community) で開催されている「LLMATCHミニ講義」用の教材となります。
#
#
# 本教材では以下のモデルの推論を行います。
# https://huggingface.co/llm-jp/llm-jp-3.1-1.8b-instruct4

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install torch>=2.3.0 transformers>=4.40.1 tokenizers>=0.19.1 accelerate>=0.29.3

# %% [markdown]
# 以下のコードでモデルを読み込みます。

# %%
import torch
from transformers import AutoTokenizer, AutoModelForCausalLM
tokenizer = AutoTokenizer.from_pretrained("llm-jp/llm-jp-3.1-1.8b-instruct4")
model = AutoModelForCausalLM.from_pretrained("llm-jp/llm-jp-3.1-1.8b-instruct4", device_map="auto", torch_dtype=torch.bfloat16)

# %% [markdown]
# 読み込んだモデルで推論します。

# %%
chat = [
    {"role": "system", "content": "以下は、タスクを説明する指示です。要求を適切に満たす応答を書きなさい。"},
    {"role": "user", "content": "司馬遼太郎の代表作をリストアップしてください。"},
]
tokenized_input = tokenizer.apply_chat_template(chat, add_generation_prompt=True, tokenize=True, return_tensors="pt").to(model.device)
with torch.no_grad():
    output = model.generate(
        tokenized_input,
        max_new_tokens=100,
        do_sample=True,
        top_p=0.95,
        temperature=0.7,
        repetition_penalty=1.05,
    )[0]
print(tokenizer.decode(output))
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:2 for open-end generation.
# <s> 以下は、タスクを説明する指示です。要求を適切に満たす応答を書きなさい。
#
# ### 指示:
# 司馬遼太郎の代表作をリストアップしてください。
#
# ### 応答:
# 司馬遼太郎は歴史小説の分野で非常に有名な作家であり、多くの作品が高く評価されています。以下に、彼の代表作をいくつか挙げます。
#
# 1. **「街道をゆく」** - このシリーズは紀行文で、各地の歴史や文化について詳しく紹介しています。ただし、厳密には小説というよりもエッセイ集と言えるでしょう。
# 2. **「新選組始末記」** - 新選組を題材にした作品で、歴史的な事実を基にしつつ、司馬遼太郎独自の視点から
